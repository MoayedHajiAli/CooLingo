# %%
# %load_ext autoreload
# %autoreload 2

from IPython.display import Audio
import os
from text_to_speach_utils.text_to_speach import convertTextToSpeach

try:
    import TTS
except:
    # !pip install tts
    import TTS
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
text = "اربك تكست هو اول موقع يسمح لزواره الكرام بتحويل الكتابة العربي الى كتابة مفهومة من قبل اغلب برامج التصميم"

output_path = os.getcwd()
output_path = os.path.join(output_path, "text_to_speach_utils")
output_path = os.path.join(output_path, "output_speach")

audio_path = convertTextToSpeach(text, )
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /tmp/ipykernel_82975/3914027451.py in <module>
#       5 output_path = os.path.join(output_path, "output_speach")
#       6
# ----> 7 audio_path = convertTextToSpeach(text, )
#
# TypeError: convertTextToSpeach() missing 1 required positional argument: 'output_path'

# %%
Audio(audio_path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

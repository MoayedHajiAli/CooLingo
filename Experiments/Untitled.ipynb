# %%
# %load_ext autoreload
# %autoreload 2

from IPython.display import Audio
import os
from text_to_speach_utils.text_to_speach import convertTextToSpeach

try:
    import TTS
except:
    # !pip install tts
    import TTS
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
text = "Hi, My name is Saria, I hope you have a great day. This is the function that converts a text into speach"
audio_path = convertTextToSpeach(text, os.getcwd());
# Out:
#  > tts_models/en/ljspeech/tacotron2-DDC is already downloaded.
#  > vocoder_models/en/ljspeech/hifigan_v2 is already downloaded.
#  > Using model: Tacotron2
#  > Model's reduction rate `r` is set to: 1
#  > Vocoder Model: hifigan
#  > Generator Model: hifigan_generator
#  > Discriminator Model: hifigan_discriminator
# Removing weight norm...
#  > Text: Hi, My name is Saria, I hope you have a great day. This is the function that converts a text into speach
#  > Text splitted to sentences.
# ['Hi, My name is Saria, I hope you have a great day.', 'This is the function that converts a text into speach']
#  > Processing time: 2.3642191886901855
#  > Real-time factor: 0.29766029320424464
#  > Saving output to /home/sarieh/gitkraken/Graduation-project/Experiments/output_speach.wav

# %%
Audio(audio_path)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
import os 
while not os.path.exists("src"):
    os.chdir('../')
os.getcwd()
# Out:
# '/scratch/users/mali18/CooLingo'

# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# ## Import and initialize TTS model

# %%
# !cd src/modules/TTS_repo/ && git checkout 4132240 && python setup.py develop

# %%
# !cd src/modules/TTS_repo/ && pip install -r requirements.txt

# %%
import TTS

# %%
from src.glowTts import GlowTts

tts = GlowTts()
# Out:
# 2022-03-15 15:30:58.479799: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
#  > Setting up Audio Processor...
#  | > sample_rate:22050
#  | > resample:False
#  | > num_mels:80
#  | > min_level_db:-100
#  | > frame_shift_ms:None
#  | > frame_length_ms:None
#  | > ref_level_db:0
#  | > fft_size:1024
#  | > power:1.1
#  | > preemphasis:0.0
#  | > griffin_lim_iters:60
#  | > signal_norm:False
#  | > symmetric_norm:True
#  | > mel_fmin:50.0
#  | > mel_fmax:7600.0
#  | > spec_gain:1.0
#  | > stft_pad_mode:reflect
#  | > max_norm:1.0
#  | > clip_norm:True
#  | > do_trim_silence:True
#  | > trim_db:60
#  | > do_sound_norm:False
#  | > stats_path:None
#  | > hop_length:256
#  | > win_length:1024
#  > Using model: glow_tts
# /scratch/users/mali18/CooLingo/src/modules/TTS_repo/TTS/tts/layers/glow_tts/glow.py:83: UserWarning: torch.qr is deprecated in favor of torch.linalg.qr and will be removed in a future PyTorch release.
# ...

# %% [markdown]
# ## Generate voice from text

# %%
# %%time
generated_wav = tts.generate_voice(
    "Hello There! This is the best design project team again. As always, nice to meet you!",
    length_scale=1.0,
    noise_scale=0.1,
    use_cuda=True)[-1]
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
# CPU times: user 193 ms, sys: 710 ms, total: 904 ms
# Wall time: 2.32 s

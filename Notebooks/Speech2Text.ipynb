# %%
import os 
while not os.getcwd().endswith('CooLingo'):
    os.chdir('../')
os.getcwd()
# Out:
# '/scratch/users/mali18/CooLingo'

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from src.speech2text import SpeechToText
from IPython.display import Audio

# %%
model = SpeechToText()

# %%
sample_input_file = 'audio_output/output_speach.wav'
Audio(sample_input_file)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/x-wav;base64,..." type="audio/x-wav" />
#                     Your browser does not support the audio element.
#                 </audio>

# %%
text = model.speech_to_text(sample_input_file)
# Out:
# Google Speech: hi my name is Siri I hope you have a great day
